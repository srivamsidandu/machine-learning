# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[4,5,6,7,8]

# %%
x,y
# Out:
# ([1, 2, 3, 4, 5], [4, 5, 6, 7, 8])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("line plot")
# Out:
# Text(0.5, 1.0, 'line plot')

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
plt.hist(x)
# Out:
# (array([1., 0., 1., 0., 0., 1., 0., 1., 0., 1.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
a=[1,2,2,3,4,5,5,5]

# %%
plt.hist(a)           # hist is for particular column
# Out:
# (array([1., 0., 2., 0., 0., 1., 0., 1., 0., 3.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
import pandas as pd

# %%
data = pd.read_excel("C:/MLDATASETS/Data.xlsx")

# %%
data
# Out:
#    country   age   salary purchased
# 0   france  44.0  72000.0        no
# 1    spain  27.0  48000.0       yes
# 2  germany  30.0  54000.0        no
# 3    spain  38.0  61000.0        no
# 4  germany  40.0      NaN       yes
# 5   france  35.0  58000.0       yes
# 6    spain   NaN  52000.0        no
# 7   france  48.0  79000.0       yes
# 8  germany  50.0  83000.0        no
# 9   france  37.0  67000.0       yes

# %%
plt.hist(data['country'])
# Out:
# (array([4., 0., 0., 0., 0., 3., 0., 0., 0., 3.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(data['age'],data['salary'])

# %%
plt.hist(data['age'])
# Out:
# (array([1., 1., 0., 1., 2., 1., 0., 1., 0., 2.]),
#  array([27. , 29.3, 31.6, 33.9, 36.2, 38.5, 40.8, 43.1, 45.4, 47.7, 50. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28e17711850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x28e17711f70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x28e177114c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x28e177206d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28e17720a60>],
#  'means': []}

# %%
plt.boxplot([1,2,3,4,30])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28e178a5dc0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x28e178b5460>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x28e178a5a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x28e178b5b80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28e178b5f10>],
#  'means': []}

# %%
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x28e17910550>,
# ...
#  [Text(1.075962358309037, 0.22870287165240302, ''),
#   Text(0.7360436312779136, 0.817459340184711, ''),
#   Text(-0.33991877217145816, 1.046162142464278, ''),
#   Text(-1.0759623315431446, -0.2287029975759841, ''),
#   Text(0.5500001932481627, -0.9526278325909777, '')])

# %%
plt.bar(data['country'],data['salary'])#using bar because one is categorical value(country)and the other is numerical(salary)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar(data['purchased'],data['age'])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.scatter(data['age'],data['salary']) #using scatter because both age and salary are in numeric values
